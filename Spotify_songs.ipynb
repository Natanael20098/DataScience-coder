# %%
import pandas as pd
import numpy as np

spotify_csv = pd.read_csv("/Users/natanael/Desktop/Data Science - Coderhouse/Dataset/Entregable001_Spotify.csv",index_col='genre') # se define como indice la columna de generos.

# %%
spotify_csv.head()
# Out:
#                       artist                    song  duration_ms  explicit  \
# genre
# pop           Britney Spears  Oops!...I Did It Again       211160     False
# rock, pop          blink-182    All The Small Things       167066     False
# pop, country      Faith Hill                 Breathe       250546     False
# rock, metal         Bon Jovi            It's My Life       224493     False
# pop                   *NSYNC             Bye Bye Bye       200560     False
#
#               year  popularity  danceability  energy  key  loudness  mode  \
# genre
# pop           2000          77         0.751   0.834    1    -5.444     0
# rock, pop     1999          79         0.434   0.897    0    -4.918     1
# pop, country  1999          66         0.529   0.496    7    -9.007     1
# rock, metal   2000          78         0.551   0.913    0    -4.063     0
# pop           2000          65         0.614   0.928    8    -4.806     0
#
# ...

# %%
spotify_csv.describe()
# Out:
#          duration_ms        year   popularity  danceability       energy  \
# count    2000.000000  2000.00000  2000.000000   2000.000000  2000.000000
# mean   228748.124500  2009.49400    59.872500      0.667438     0.720366
# std     39136.569008     5.85996    21.335577      0.140416     0.152745
# min    113000.000000  1998.00000     0.000000      0.129000     0.054900
# 25%    203580.000000  2004.00000    56.000000      0.581000     0.622000
# 50%    223279.500000  2010.00000    65.500000      0.676000     0.736000
# 75%    248133.000000  2015.00000    73.000000      0.764000     0.839000
# max    484146.000000  2020.00000    89.000000      0.975000     0.999000
#
#                key     loudness         mode  speechiness  acousticness  \
# count  2000.000000  2000.000000  2000.000000  2000.000000   2000.000000
# mean      5.378000    -5.512434     0.553500     0.103568      0.128955
# std       3.615059     1.933482     0.497254     0.096159      0.173346
# ...

# %%
spotify_csv.sort_index() # ordenamos el indice
# Out:
#                                  artist                         song  \
# genre
# Dance/Electronic                  Flume                       Say It
# Dance/Electronic          Petit Biscuit                 Sunset Lover
# Dance/Electronic                Chicane                Don't Give Up
# Dance/Electronic  The Chemical Brothers                    Galvanize
# Dance/Electronic                  Flume            Never Be Like You
# ...                                 ...                          ...
# set()                           Wheatus              Teenage Dirtbag
# set()                     Blazin' Squad      Crossroads - Radio Edit
# set()                         DJ Casper  Cha Cha Slide - Hardino Mix
# set()                      Milky Chance                 Stolen Dance
# set()                     Elliott Yamin                 Wait for You
#
#                   duration_ms  explicit  year  popularity  danceability  \
# genre
# ...
